# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_excel("/content/melb_data.xlsx")
dataset.head(10)
# Out:
#        Suburb             Address  Rooms Type    Price Method SellerG  \
# 0  Abbotsford        85 Turner St      2    h  1480000      S  Biggin
# 1  Abbotsford     25 Bloomburg St      2    h  1035000      S  Biggin
# 2  Abbotsford        5 Charles St      3    h  1465000     SP  Biggin
# 3  Abbotsford    40 Federation La      3    h   850000     PI  Biggin
# 4  Abbotsford         55a Park St      4    h  1600000     VB  Nelson
# 5  Abbotsford      129 Charles St      2    h   941000      S  Jellis
# 6  Abbotsford        124 Yarra St      3    h  1876000      S  Nelson
# 7  Abbotsford       98 Charles St      2    h  1636000      S  Nelson
# 8  Abbotsford  6/241 Nicholson St      1    u   300000      S  Biggin
# 9  Abbotsford       10 Valiant St      2    h  1097000      S  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0 2016-12-03       2.5    3067.0  ...         1  1.0     202.0           NaN
# ...

# %%
dataset.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode          138
# hoal              118
# Bathroom            0
# Car               144
# Landsize          121
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1487
# Lattitude          36
# Longtitude         71
# Regionname         15
# Propertycount      92
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  int64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  datetime64[ns]
#  8   Distance       13580 non-null  float64
#  9   Postcode       13442 non-null  float64
#  10  hoal           13462 non-null  float64
#  11  Bathroom       13580 non-null  int64
#  12  Car            13436 non-null  float64
#  13  Landsize       13459 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12093 non-null  object
# ...

# %%
dataset.select_dtypes(include="float64").columns
# Out:
# Index(['Distance', 'Postcode', 'hoal', 'Car', 'Landsize', 'BuildingArea',
#        'YearBuilt', 'Lattitude', 'Longtitude', 'Propertycount'],
#       dtype='object')

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer(strategy="mean")
ar = si.fit_transform(dataset[['Distance','Postcode','hoal','Car','Landsize','BuildingArea','YearBuilt','Lattitude','Longtitude','Propertycount']])

# %%
pd.DataFrame(ar,columns = dataset.select_dtypes(include="float64").columns)
# Out:
#        Distance  Postcode      hoal  Car  Landsize  BuildingArea    YearBuilt  \
# 0           2.5    3067.0  2.000000  1.0     202.0     151.96765  1964.684217
# 1           2.5    3067.0  2.000000  0.0     156.0      79.00000  1900.000000
# 2           2.5    3067.0  3.000000  0.0     134.0     150.00000  1900.000000
# 3           2.5    3067.0  2.916134  1.0      94.0     151.96765  1964.684217
# 4           2.5    3067.0  3.000000  2.0     120.0     142.00000  2014.000000
# ...         ...       ...       ...  ...       ...           ...          ...
# 13575      16.7    3150.0  4.000000  2.0     652.0     151.96765  1981.000000
# 13576       6.8    3016.0  3.000000  2.0     333.0     133.00000  1995.000000
# 13577       6.8    3016.0  3.000000  4.0     436.0     151.96765  1997.000000
# 13578       6.8    3016.0  4.000000  5.0     866.0     157.00000  1920.000000
# 13579       6.3    3013.0  4.000000  1.0     362.0     112.00000  1920.000000
#
# ...

# %%
new_dataset = pd.DataFrame(ar,columns = dataset.select_dtypes(include="float64").columns)

# %%
new_dataset.isnull().sum()
# Out:
# Distance         0
# Postcode         0
# hoal             0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# Lattitude        0
# Longtitude       0
# Propertycount    0
# dtype: int64

# %%
new_dataset
# Out:
#        Distance  Postcode      hoal  Car  Landsize  BuildingArea    YearBuilt  \
# 0           2.5    3067.0  2.000000  1.0     202.0     151.96765  1964.684217
# 1           2.5    3067.0  2.000000  0.0     156.0      79.00000  1900.000000
# 2           2.5    3067.0  3.000000  0.0     134.0     150.00000  1900.000000
# 3           2.5    3067.0  2.916134  1.0      94.0     151.96765  1964.684217
# 4           2.5    3067.0  3.000000  2.0     120.0     142.00000  2014.000000
# ...         ...       ...       ...  ...       ...           ...          ...
# 13575      16.7    3150.0  4.000000  2.0     652.0     151.96765  1981.000000
# 13576       6.8    3016.0  3.000000  2.0     333.0     133.00000  1995.000000
# 13577       6.8    3016.0  3.000000  4.0     436.0     151.96765  1997.000000
# 13578       6.8    3016.0  4.000000  5.0     866.0     157.00000  1920.000000
# 13579       6.3    3013.0  4.000000  1.0     362.0     112.00000  1920.000000
#
# ...

# %%
dataset["BuildingArea"].mean()
# Out:
# np.float64(151.96764988779805)
