# %%
import pandas as pd

# %%
df = pd.DataFrame({"name":["wscube","cow","cat","dog","black"]})
df
# Out:
#      name
# 0  wscube
# 1     cow
# 2     cat
# 3     dog
# 4   black
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_31['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_32['en_data'].plot(kind='hist', bins=20, title='en_data')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_33.groupby('name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df["en_data"] = le.fit_transform(df["name"])

# %%
df
# Out:
#      name  en_data
# 0  wscube        4
# 1     cow        2
# 2     cat        1
# 3     dog        3
# 4   black        0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_41['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_42['en_data'].plot(kind='hist', bins=20, title='en_data')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_43.groupby('name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
dataset =  pd.read_excel("/content/melb_data.xlsx")
dataset.head(5)
# Out:
#        Suburb           Address  Rooms Type    Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0 2016-12-03       2.5    3067.0  ...         1  1.0     202.0           NaN
# 1 2016-02-04       2.5    3067.0  ...         1  0.0     156.0          79.0
# 2 2017-03-04       2.5    3067.0  ...         2  0.0     134.0         150.0
# 3 2017-03-04       2.5    3067.0  ...         2  1.0      94.0           NaN
# 4 2016-06-04       2.5    3067.0  ...         1  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
dataset["Regionname"].unique()
# Out:
# array(['Northern Metropolitan', 'Western Metropolitan',
#        'Southern Metropolitan', nan, 'Eastern Metropolitan',
#        'South-Eastern Metropolitan', 'Eastern Victoria',
#        'Northern Victoria', 'Western Victoria'], dtype=object)

# %%
la = LabelEncoder()
la.fit(dataset["Regionname"])
# Out:
# LabelEncoder()

# %%
la = LabelEncoder()
la.fit(dataset["Regionname"])
print(la.classes_)
# Out:
# ['Eastern Metropolitan' 'Eastern Victoria' 'Northern Metropolitan'
#  'Northern Victoria' 'South-Eastern Metropolitan' 'Southern Metropolitan'
#  'Western Metropolitan' 'Western Victoria' nan]

# %%
la.transform(dataset["Regionname"])
# Out:
# array([2, 2, 2, ..., 6, 6, 6])
