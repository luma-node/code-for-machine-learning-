# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_confusion_matrix

# %%
dataset = pd.read_excel("/content/placement.xlsx")

# %%
dataset.head(3)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     2.36
# 2  7.82     3.36

# %%
#sns.kdeplot(data=dataset["cgpa"])
#plt.show()

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(x="cgpa",y="package",data=dataset,hue="package")
plt.show()

# %%
x = dataset.iloc[:,:-1]
y = dataset["package"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
import numpy as np
from sklearn.naive_bayes import GaussianNB

y_train_class = np.where(y_train > y_train.mean(), 1, 0)
y_test_class = np.where(y_test > y_train.mean(), 1, 0)

gnb = GaussianNB()
gnb.fit(x_train, y_train_class)
y_pred = gnb.predict(x_test)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB

# %%
gnb = GaussianNB()

# %%
gnb.fit(x_train,y_train)

# %%
gnb.score(x_test,y_test)*100 , gnb.package(x_train,y_train)*100

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2285653783.py in <cell line: 0>()
#       1 plt.figure(figsize=(4,3))
# ----> 2 plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=gnb)
#       3 plt.show()
#
# NameError: name 'plot_decision_regions' is not defined

# %%
mnb = MultinomialNB()
mnb.fit(x_train,y_train)

# %%
mnb.score(x_test,y_test)*100 , gnb.package(x_train,y_train)*100

# %%
bnb = BernoulliNB()
bnb.fit(x_train,y_train)

# %%
bnb.score(x_test,y_test)*100 , bnb.package(x_train,y_train)*100
