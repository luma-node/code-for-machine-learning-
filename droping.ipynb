# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df =  pd.read_excel("/content/melb_data.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  int64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  datetime64[ns]
#  8   Distance       13580 non-null  float64
#  9   Postcode       13442 non-null  float64
#  10  hoal           13462 non-null  float64
#  11  Bathroom       13580 non-null  int64
#  12  Car            13436 non-null  float64
#  13  Landsize       13459 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12093 non-null  object
#  17  Lattitude      13544 non-null  float64
#  18  Longtitude     13509 non-null  float64
#  19  Regionname     13565 non-null  object
#  20  Propertycount  13488 non-null  float64
# dtypes: datetime64[ns](1), float64(10), int64(3), object(7)
# memory usage: 2.2+ MB

# %%
dataset = pd.read_excel("/content/melb_data.xlsx")
dataset.head(14)
# Out:
#         Suburb              Address  Rooms Type    Price Method SellerG  \
# 0   Abbotsford         85 Turner St      2    h  1480000      S  Biggin
# 1   Abbotsford      25 Bloomburg St      2    h  1035000      S  Biggin
# 2   Abbotsford         5 Charles St      3    h  1465000     SP  Biggin
# 3   Abbotsford     40 Federation La      3    h   850000     PI  Biggin
# 4   Abbotsford          55a Park St      4    h  1600000     VB  Nelson
# 5   Abbotsford       129 Charles St      2    h   941000      S  Jellis
# 6   Abbotsford         124 Yarra St      3    h  1876000      S  Nelson
# 7   Abbotsford        98 Charles St      2    h  1636000      S  Nelson
# 8   Abbotsford   6/241 Nicholson St      1    u   300000      S  Biggin
# 9   Abbotsford        10 Valiant St      2    h  1097000      S  Biggin
# 10  Abbotsford   411/8 Grosvenor St      2    u   700000     VB  Jellis
# 11  Abbotsford      40 Nicholson St      3    h  1350000     VB  Nelson
# 12  Abbotsford  123/56 Nicholson St      2    u   750000      S  Biggin
# 13  Abbotsford        45 William St      2    h  1172500      S  Biggin
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  2016-12-03       2.5    3067.0  ...         1  1.0     202.0           NaN
# 1  2016-02-04       2.5    3067.0  ...         1  0.0     156.0          79.0
# 2  2017-03-04       2.5    3067.0  ...         2  0.0     134.0         150.0
# 3  2017-03-04       2.5    3067.0  ...         2  1.0      94.0           NaN
# 4  2016-06-04       2.5    3067.0  ...         1  2.0     120.0         142.0
# 5  2016-05-07       2.5    3067.0  ...         1  NaN     181.0           NaN
# 6  2016-05-07       2.5    3067.0  ...         2  NaN     245.0         210.0
# 7  2016-10-08       2.5    3067.0  ...         1  2.0     256.0         107.0
# 8  2016-10-08       2.5       NaN  ...         1  NaN       0.0           NaN
# 9  2016-10-08       2.5       NaN  ...         1  NaN     220.0          75.0
# 10 2016-11-12       2.5       NaN  ...         2  NaN       0.0           NaN
# 11 2016-11-12       2.5    3067.0  ...         2  2.0     214.0         190.0
# 12 2016-11-12       2.5       NaN  ...         2  1.0       0.0          94.0
# 13 2016-08-13       2.5    3067.0  ...         1  1.0     195.0           NaN
#
#     YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0         NaN        Yarra       NaN    144.9984  Northern Metropolitan
# 1      1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2      1900.0          NaN  -37.8093         NaN  Northern Metropolitan
# 3         NaN        Yarra  -37.7969    144.9969  Northern Metropolitan
# 4      2014.0        Yarra  -37.8072    144.9941  Northern Metropolitan
# 5         NaN        Yarra       NaN         NaN  Northern Metropolitan
# 6      1910.0        Yarra  -37.8024    144.9993  Northern Metropolitan
# 7      1890.0        Yarra  -37.8060    144.9954  Northern Metropolitan
# 8         NaN        Yarra  -37.8008         NaN  Northern Metropolitan
# 9      1900.0        Yarra  -37.8010    144.9989  Northern Metropolitan
# 10        NaN        Yarra       NaN    145.0067  Northern Metropolitan
# 11     2005.0        Yarra  -37.8085    144.9964  Northern Metropolitan
# 12     2009.0        Yarra  -37.8078         NaN  Northern Metropolitan
# 13        NaN        Yarra  -37.8084    144.9973  Northern Metropolitan
#
#    Propertycount
# 0         4019.0
# 1         4019.0
# 2         4019.0
# 3         4019.0
# 4         4019.0
# 5         4019.0
# 6         4019.0
# 7         4019.0
# 8         4019.0
# 9         4019.0
# 10        4019.0
# 11        4019.0
# 12        4019.0
# 13        4019.0
#
# [14 rows x 21 columns]

# %%
dataset.shape
# Out:
# (13580, 21)

# %%
dataset.shape
# Out:
# (5921, 20)

# %%
((13580-5921)/13580)*100
# Out:
# 56.39911634756996

# %%
dataset.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode          138
# hoal              118
# Bathroom            0
# Car               144
# Landsize          121
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1487
# Lattitude          36
# Longtitude         71
# Regionname         15
# Propertycount      92
# dtype: int64

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.drop(columns=["Car"],inplace=True)

# %%
dataset.dropna(inplace=True)
